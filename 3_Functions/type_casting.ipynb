# %%
[].append('amit')

# %%
c = "233"

int_v = int(c)
str_v = str(c)

print(type(int_v), type(str_v), bool(c), float(c))
# Out:
# <class 'int'> <class 'str'> True 233.0

# %%
user_input = input("enter something..")
print(user_input, type(user_input))
# Out:
# 45 <class 'str'>

# %%
'''
Types of operators:
    1) Arithmetic Operator   ( + - * / % // ** )
    2) Comparision Operator  ( == , !=, >=, <=)
    3) Logical Operator      ( and , or,  not )
    4) Assignment Operator    ( = +=, -=, *=, /=, **/, //=)
    5) Membership Operator  ( in, not in )
    6) Identity Operator ( is, not is )
'''

'''
List:  list is ordered, mutable collections of items
tuple: tuple is ordered, immutable collections of items
set:  it is unordered, unique colletion of items
dict: it is a collection of key value pairs..
'''
# Out:
# '\nList:  list is ordered, mutable collections of items\ntuple: tuple is ordered, immutable collections of items\nset:  it is unordered, unique colletion of items\ndict: it is a collection of key value pairs..\n'

# %%
lst = [2,3,4,5,5,6,7,8,8,6,32,4,3,5,5,4,4555]
newlst = list(filter(lambda x: x%3==0, lst))
newlst
# Out:
# [3, 6, 6, 3]

# %%
# ## Common list methods:
# ''''
'''
append(item)
remove(element)
sort()
reverse()
pop()
insert(index, value)
'''
# Out:
# [212, 2, 3, 4, 5, 6, 7, 8, 8, 6, 32, 4, 3, 5, 5, 4, 4555, 23]

# %%
r = [121,132,143,32,99,10,345,65,76,78,66]

r.reverse()
r
# Out:
# [66, 78, 76, 65, 345, 10, 99, 32, 143, 132, 121]

# %%
r.sort()
r
# Out:
# [10, 32, 65, 66, 76, 78, 99, 121, 132, 143, 345]

# %%
tuples = (2,3,4,5,6,76,5,4,3,2)
print(tuples)
# Out:
# (2, 3, 4, 5, 6, 76, 5, 4, 3, 2)

# %%
tuples.count(2)
tuples.index(5)

'''
tuples.count(value)
tuples.index(value)

'''

tuple_to_list = list(tuples)
# tuple_to_list. append() .pop()  .remove(elemtn)  .insert(index, value), .sort(),  .reverse()
# Out:
# [2, 3, 4, 5, 6, 76, 5, 4, 3, 2]

# %%
## Set  and Set Methods/Operations

'''
set methods:
    sett.add(33)
    sett.remove(22)
    sett.pop()  # last element
    sett.discard(item_name) 
'''

sett = {3,4,5,6,5,4,3,2,3,4,5,6,7}
sett
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
sett.remove(3)

# %%
sett
# Out:
# {2, 4, 5, 6, 7}

# %%
sett.add(23)

# %%
sett
# Out:
# {2, 4, 5, 6, 7, 23}

# %%
sett.discard(6)
sett
# Out:
# {2, 4, 5, 7, 23}

# %%
sett.add(111); sett
# Out:
# {2, 4, 5, 7, 23, 111}

# %%
# set operations

A = {1,2,3,4,5}
B = {4,5,6,7,8}

print(A.intersection(B))
print(A.union(B))
# Out:
# {4, 5}
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
B.intersection(A)
print(A, B)

print(A.difference(B))
# Out:
# {1, 2, 3, 4, 5} {4, 5, 6, 7, 8}
# {1, 2, 3}

# %%
#### Dictionary and its methods and Operations

dt = {1:1, 2:2, 3:4, 5:56, 7:34}
dt.keys()
# Out:
# dict_keys([1, 2, 3, 5, 7])

# %%
dt.values()
# Out:
# dict_values([1, 2, 4, 56, 34])

# %%
dt.items()
# Out:
# dict_items([(1, 1), (2, 2), (3, 4), (5, 56), (7, 34)])

# %%
'''
dictionary methods:
    dt.keys()
    dt.items()
    dt.values()
    dt.pop()
    dt.popitem(item_name)
    dt.clear()

'''
