# %%
st = 'hi python okay'
st.title()
# Out:
# 'Hi Python Okay'

# %%
st.capitalize()
# Out:
# 'Hi python okay'

# %%
st.upper()
# Out:
# 'HI PYTHON OKAY'

# %%
### String Methods

# upper()
# lower()
# # title()   // first letter of each word capital
# capitalize()   # first letter capital

# strip()
# lstrip()
# rstrip()

# find()
# replace()

# fruits = "apple, mango, orange"
# fruits.split(",")   ['appe', 'mango', 'orange']
# " - ".join(fruits)  # o/p: apple - mango - orange


stt = "Python123"

# stt.isalpha()  # only alphabates
# stt.isdigit()  # contains only digits
# stt.isalnum()
# stt.isspace()

# Built in function(methods)

len("ii")
ord('A')  ## 65
chr(65)   ## A

print("hi {}. what is your favorite program in: {}".format("amit", "python"))
# Out:
# hi amit. what is your favorite program in: python

# %%
pii = 3.1442344

print(f"this is pii value: {pii:.2f}")
# Out:
# this is pii value: 3.14

# %%
st = "python love ok"

print(f"{st:^10}")
# Out:
# python love ok

# %%
s = st.encode()
print(s)
s.decode()
# Out:
# b'python love ok'
# 'python love ok'

# %%
'''
st = "hi python okay my lang"
st.upper()
st.lower()
st.capitalize()
st.title()

st.find("is")
st.replace("is", "are")

st.strip()
st.lstrip()
st.rstrip()

" ".join(st)
st.split(" ")

len(st)
chr(65)
ord("A")

st.isalpha()
st.isdigit()
st.isalnum()
st.isspace()

# ====================================================
'''
