# %%
# Array

import array

ar = array.array("i", [1,2,3,4])
ar
# Out:
# array('i', [1, 2, 3, 4])

# %%
import random

random_val = random.randint(1,100)
print(random_val)

radom_choice = random.choice(['a','b','c','d', 'e', 'f'])  # random value every time..
print(radom_choice)
# Out:
# 6
# d

# %%
import os


os.getcwd()
# Out:
# '/home/amitgupta/Documents/python_with_ml_ai/4_Package_Modules/4.1 StandardLIbrary'

# %%
os.makedirs('test_dir_by_os_command', exist_ok=True)

# %%
# High level operation on file...

import shutil

shutil.copyfile('./source_test.txt', 'destination_test.txt')
# Out:
# 'destination_test.txt'

# %%
# Data Serialization

import json

data = {'name':"Rajes", 'age':34, 'city':"Indore"}

json_str = json.dumps(data)
print(json_str)

json_data = json.loads(json_str)
print(json_data)
# Out:
# {"name": "Rajes", "age": 34, "city": "Indore"}
# {'name': 'Rajes', 'age': 34, 'city': 'Indore'}

# %%
import re 

txt = "Hi this is my 2 nd number and 3 rd number i will be on 112 days get.."
pattern = r'\d+'

find = re.findall(pattern, txt)
print(find)
# Out:
# ['2', '3', '112']
