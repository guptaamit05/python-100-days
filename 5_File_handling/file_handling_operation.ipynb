# %%
a = []
a.insert(0,22)

# %%
ft = open('example.txt', 'a')
ft.write("\n Okay now new line on 25 June 2026")
ft.close()

try:
    f = open('example.txt', 'r')
    # content = f.read()
    for line in f:
        print(" line==== ", line)
    f.close()
except Exception as e:
    print("Error: ", e)
# Out:
#  line====  this is exaple
#
#  line====  fldk
#
#  line====   sdf as asdfaskld fldk
#
#  line====   asdfk alskja
#
#  line====   asdkf jaklsdfklasd fldknew line with append method...nnew line with append method...
#
#  line====  new line with append method...
#
#  line====  new line with append method...fisrt line second lnetird line..
#
#  line====   Okay now new line on 25 June 2026
#
#  line====   Okay now new line on 25 June 2026

# %%
import os
os.getcwd()
# Out:
# '/home/amitgupta/Documents/python_with_ml_ai/5_File_handling'

# %%
os.listdir()
# Out:
# ['fileoperation.ipynb',
#  'log_transaction.txt',
#  'filehandlingquestions',
#  'example.txt',
#  'file_path.ipynb',
#  'file_handling_operation.ipynb',
#  'exceptionhandlingsolution']

# %%
os.mkdir("directory_name_here")
os.makedirs("abc/test/test2_2")

# %%
# os.remove('file_name_to_remove')  ## ex:  os.remove('text.txt')
# os.rmdir('abc')   # remove emtpy directory only

import shutil
shutil.rmtree('abc')
os.rmdir('directory_name_here')

# %%
if os.path.exists('test.txt'):
    print("File exists")
else:
    print("Not Exist")
# Out:
# Not Exist

# %%
'''
#  python3 -m venv my_venv_name
# to activate: source my_venv_name/bin/activate
## pip freeze > requirements.txt
## pip install -r requirements.txt
## deactivate

'''
# Out:
# '\n#  python3 -m venv my_venv_name\n# to activate: source my_venv_name/bin/activate\n## pip freeze > requirements.txt\n## pip install -r requirements.txt\n## deactivate\n\n'

# %%
import requests

url = "https://api.github.com/users/octocat"
data = requests.get(url)

if data.status_code != 200:
    print("data not found")
else:
    da = data.json()
    print(f"data = {da} ")
# Out:
# data = {'login': 'octocat', 'id': 583231, 'node_id': 'MDQ6VXNlcjU4MzIzMQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/583231?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/octocat', 'html_url': 'https://github.com/octocat', 'followers_url': 'https://api.github.com/users/octocat/followers', 'following_url': 'https://api.github.com/users/octocat/following{/other_user}', 'gists_url': 'https://api.github.com/users/octocat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/octocat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/octocat/subscriptions', 'organizations_url': 'https://api.github.com/users/octocat/orgs', 'repos_url': 'https://api.github.com/users/octocat/repos', 'events_url': 'https://api.github.com/users/octocat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/octocat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': 'The Octocat', 'company': '@
# ...

# %%
import re

et = "test of indai, the, test of iaoer in the overdraf fac to the iowe is good but need to very in the sky"
e = re.search('the', et)
print(e.start())
print(e.end())
# Out:
# 15
# 18

# %%
se = re.findall('the', et, re.IGNORECASE)
print(se)
# Out:
# ['the', 'the', 'the', 'the']

# %%
s = re.sub('the', "THE",et)
print(et)
print(s)
# Out:
# test of indai, the, test of iaoer in the overdraf fac to the iowe is good but need to very in the sky
# test of indai, THE, test of iaoer in THE overdraf fac to THE iowe is good but need to very in THE sky

# %%
int("15")+5
# Out:
# 20

# %%
'23'==23
# Out:
# False
