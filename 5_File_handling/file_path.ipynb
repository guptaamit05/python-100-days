# %%
print("ok")
# Out:
# ok

# %%
import os

# %%
os.listdir()
# Out:
# ['fileoperation.ipynb', 'example.txt', 'file_path.ipynb']

# %%
os.path.exists('example.txt')
# Out:
# True

# %%
os.path.isdir('example.txt')
# Out:
# False

# %%
os.path.isfile('example.txt')
# Out:
# True

# %%
os.path.pardir  # ..

os.path.abspath('example.txt')
# Out:
# '/home/amitgupta/Documents/python_with_ml_ai/5_File_handling/example.txt'
