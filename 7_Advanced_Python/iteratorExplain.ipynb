# %%
lst = [1,2,3,4,5,6]
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
iterr = iter(lst)
iterr

# %%
print(next(iterr))

try:
    print(next(iterr))
except Exception as e:
    print("Error: reached last index")
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(next(iterr))
#       2
#       3 try:
#       4     print(next(iterr))
#
# StopIteration:
