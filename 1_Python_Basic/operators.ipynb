# %%
## Operators..
a =10
b=20
print(a+b)

print( a-b)
print( a*b)
print( b/a)
print( a%b)
print( a//b)
# Out:
# 30
# -10
# 200
# 2.0
# 10
# 0

# %%
## Comparision operators..

##  ==  ===  >=  <=  
c=10
d=10
#c==d
#c!=d
# Out:
# False
