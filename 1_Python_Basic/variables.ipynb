# %%
a = 100
b = "string variable"
c = 100.45

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
## DECLERAING AND ASSIGNING VALUE..
age = 32
name="Harish"
height = 6.5
is_student = False

# %%
## valid variable name:
first_name = "harish"

# %%
## invalid variable name
1_first_name = "Amit"
first-name="Gopal"
# Out:
#   Cell In[6], line 2
#     1_first_name = "Amit"
#      ^
# SyntaxError: invalid decimal literal

# %%
## Understading variable type:
## Python is dynamically typed language..
age=12
age_str= str(age)
print(age_str)
print(age)
# Out:
# 12
# 12

# %%
type(age_str)
# Out:
# str

# %%
age = input("enter your age")
print(age, type(age))
# Out:
# 232 <class 'str'>
