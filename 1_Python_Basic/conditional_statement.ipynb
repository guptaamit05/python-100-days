# %%
a =13

if a>=18:
    print("Allowed")
else:
    print("Not allowed")
# Out:
# Not allowed

# %%
if a>14:
    print("you are okay")
elif(a>=18):
    print("okay 8")
else:
    print("under...")
# Out:
# under...

# %%
## check even odd or negative..

num = -0
if num>0:
    print("number is positive")
    if num%2==0:
        print("number is even")
    else:
        print("numbber is odd...")
else:
    print("negative number...")
    if( num%2==0):
        print("negative even number")
    else:
        print("negative odd number...")
# Out:
# negative number...
# negative even number

# %%
# Find sum of n natural number..
num = int(input("Enter any number.."))
sum = num*(num+1)//2
print(f"Sum of {num} numbers is: {sum}")
# Out:
# Sum of 5 numbers is: 15
