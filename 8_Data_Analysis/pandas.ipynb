# %%
import pandas as pd

print("ok")
# Out:
# ok

# %%
## pandas series is one-dimentional array..

data  = [1,2,3,4,5]

series = pd.Series(data)
print("Series: \n", series)
# Out:
# Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data2 = {'a':1, 'b':2, 'c':3}

d = pd.Series(data2)
print(d)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data3 = [10,20,30,40,50,60]
indx = ['a,', 'b','c', 'd', 'e','f']
s = pd.Series(data3, index=indx)
print(s)
# Out:
# a,    10
# b     20
# c     30
# d     40
# e     50
# f     60
# dtype: int64

# %%
## Dataframe ( multiple rows and columns...)

## create a dataframe from a dictionary of list..

data = {
    'name':['krish', 'anuj', 'madhav'],
    'Age':[33,44,23],
    'City':['indore', 'banglore', 'mumbai']
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  Age      City
# 0   krish   33    indore
# 1    anuj   44  banglore
# 2  madhav   23    mumbai
# <class 'pandas.DataFrame'>

# %%
## Create a DataFrame from the dictionary of list..

data = [
    {'name':'anuj', 'age':43, 'city':"kanpur"},
    {'name':'tom', 'age':34, 'city':"mumbai"},
    {'name':'Jack', 'age':24, 'city':"bhopal"},
]

t = pd.DataFrame(data)
print(t)
# Out:
#    name  age    city
# 0  anuj   43  kanpur
# 1   tom   34  mumbai
# 2  Jack   24  bhopal

# %%
csv_data = pd.read_csv('sample_data.csv')
# csv_data.head(5)

# %%
# last 5 records by tail function

# pd.tail(5)

# %%
t.loc[0]
# Out:
# name      anuj
# age         43
# city    kanpur
# Name: 0, dtype: object

# %%
t.at[2,'age']
# Out:
# np.int64(24)

# %%
t.iat[1,2]
# Out:
# 'mumbai'

# %%
t.drop('city', axis=1)
# Out:
#    name  age
# 0  anuj   43
# 1   tom   34
# 2  Jack   24

# %%
t['age'] = t['age'] +10

# %%
t
# Out:
#    name  age    city
# 0  anuj   53  kanpur
# 1   tom   44  mumbai
# 2  Jack   34  bhopal

# %%
csv_data.describe()
# Out:
#         Scan Number  3001 (°C)- TC1B  3002 (°C)- TC2B  3003 (°C)- TC3B  \
# count  12580.000000     1.258000e+04     1.258000e+04     1.258000e+04
# mean    6290.500000     5.744833e+35     5.902226e+35     6.217011e+35
# std     3631.677528     7.519861e+36     7.621567e+36     7.820918e+36
# min        1.000000    -1.238020e+02    -1.975290e+02    -1.767940e+02
# 25%     3145.750000     1.740350e+01     2.057900e+01     2.440600e+01
# 50%     6290.500000     1.953300e+01     2.315700e+01     2.783500e+01
# 75%     9435.250000     1.083465e+02     1.210045e+02     1.214988e+02
# max    12580.000000     9.900000e+37     9.900000e+37     9.900000e+37
#
#        3004 (°C)- TC4B  3005 (°C)- TC5B  3006 (°C)- TC6B  3007 (°C)- TC7B  \
# count     1.258000e+04     1.258000e+04     1.258000e+04     1.258000e+04
# mean      4.328299e+35     5.351351e+35     4.328299e+35     4.879173e+35
# std       6.531938e+36     7.259215e+36     6.531938e+36     6.933222e+36
# ...

# %%
import pandas as pd
name_data = [{'name':"harish", 'age':23, 'city':'indore'}, {'name':"punit", 'age':53, 'city':'bhopal'}, {'name':"govind", 'age':32, 'city':'pune'}]

dff = pd.DataFrame(name_data)

print(dff)
dff['age'] = dff['age']+5
dff
# Out:
#      name  age    city
# 0  harish   23  indore
# 1   punit   53  bhopal
# 2  govind   32    pune
#      name  age    city
# 0  harish   28  indore
# 1   punit   58  bhopal
# 2  govind   37    pune
